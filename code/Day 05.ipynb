# %% [markdown]
# # Advent of Code - Day 5

# %% [markdown]
# Given that I have a life, I'm probably going to minimise any commentary on these now. It's not like anyone else is every going to need it...

# %% [markdown]
# ## Part 1

# %%
import re

# %%
input_ls=open('data/day05_test').read().splitlines()

input_ls
# Out:
# ['BFFFBBFRRR', 'FFFBBBFRRR', 'BBFFBBFRLL']

# %%
# Convert to binary:

l1=[x.replace('F', '0').replace('B', '1').replace('L', '0').replace('R', '1')
   for x in input_ls]
l1
# Out:
# ['1000110111', '0001110111', '1100110100']

# %%
l2=[(int(c[:7], base=2), int(c[7:], base=2)) for c in l1]

l2
# Out:
# [(70, 7), (14, 7), (102, 4)]

# %%
max([(8*x + y) for (x, y) in l2])
# Out:
# 820

# %%
input_ls=open('data/day05_input').read().splitlines()

l1=[x.replace('F', '0').replace('B', '1').replace('L', '0').replace('R', '1')
   for x in input_ls]

l2=[(int(c[:7], base=2), int(c[7:], base=2)) for c in l1]

max([(8*x + y) for (x, y) in l2])
# Out:
# 959

# %% [markdown]
# ## Part 2

# %%
input_ls=open('data/day05_input').read().splitlines()

l1=[x.replace('F', '0').replace('B', '1').replace('L', '0').replace('R', '1')
   for x in input_ls]

l2=[(int(c[:7], base=2), int(c[7:], base=2)) for c in l1]

l3=[(8*x + y) for (x, y) in l2]

l3[:5]
# Out:
# [445, 608, 639, 948, 130]

# %%
set(range(min(l3), max(l3)))-set(l3)
# Out:
# {527}

# %% [markdown]
# Done!
